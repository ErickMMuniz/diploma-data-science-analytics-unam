# %%
df <- read.csv("habits.csv") 

df |> head()
# Out:
#   age gender study_hours_per_day social_media_hours netflix_hours part_time_job
# 1 23  Female 0.0                 1.2                1.1           No
# 2 20  Female 6.9                 2.8                2.3           No
# 3 21  Male   1.4                 3.1                1.3           No
# 4 23  Female 1.0                 3.9                1.0           No
# 5 19  Female 5.0                 4.4                0.5           No
# 6 24  Male   7.2                 1.3                0.0           No
#   attendance_percentage sleep_hours diet_quality exercise_frequency
# 1 85.0                  8.0         Fair         6
# 2 97.3                  4.6         Good         6
# 3 94.8                  8.0         Poor         1
# 4 71.0                  9.2         Poor         4
# 5 90.9                  4.9         Fair         3
# 6 82.9                  7.4         Fair         1
#   parental_education_level internet_quality mental_health_rating
# ...
